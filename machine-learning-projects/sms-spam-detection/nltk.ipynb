# %%
# !pip3 install pandas
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/alisiyakhaliulina/Library/Python/3.12/lib/python/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/alisiyakhaliulina/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip3 install --upgrade pip

# %%
import nltk

nltk.internals.config_java(options='-Djava.security.manager', verbose=False)

nltk.download()

nltk.internals.config_java(options='-Djava.security.manager', verbose=False)
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml

# %%
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords

stop_words = stopwords.words('english')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[10], line 14
#      12 import zipfile
#      13 with zipfile.ZipFile("stopwords.zip", "r") as zip_ref:
# ---> 14     zip_ref.extractall("/path/to/nltk_data/corpora")
#      16 # Использование стоп-слов из NLTK
#      17 from nltk.corpus import stopwords
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/zipfile/__init__.py:1721, in ZipFile.extractall(self, path, members, pwd)
#    1718     path = os.fspath(path)
#    1720 for zipinfo in members:
# -> 1721     self._extract_member(zipinfo, path, pwd)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/zipfile/__init__.py:1770, in ZipFile._extract_member(self, member, targetpath, pwd)
#    1768 upperdirs = os.path.dirname(targetpath)
#    1769 if upperdirs and not os.path.exists(upperdirs):
# -> 1770     os.makedirs(upperdirs)
#    1772 if member.is_dir():
#    1773     if not os.path.isdir(targetpath):
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:215, in makedirs(name, mode, exist_ok)
#
# File <frozen os>:225, in makedirs(name, mode, exist_ok)
#
# OSError: [Errno 30] Read-only file system: '/path'

# %%
import pandas as pd

# %%
df = pd.read_csv('SMSSpamCollection', sep = '\t')

# %%
df.head()
# Out:
#     ham  \
# 0   ham
# 1  spam
# 2   ham
# 3   ham
# 4  spam
#
#   Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...
# 0                      Ok lar... Joking wif u oni...
# 1  Free entry in 2 a wkly comp to win FA Cup fina...
# 2  U dun say so early hor... U c already then say...
# 3  Nah I don't think he goes to usf, he lives aro...
# 4  FreeMsg Hey there darling it's been 3 week's n...

# %%
df.columns = ['Labell', 'Text']

# %%
df
# Out:
#      Labell                                               Text
# 0       ham                      Ok lar... Joking wif u oni...
# 1      spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 2       ham  U dun say so early hor... U c already then say...
# 3       ham  Nah I don't think he goes to usf, he lives aro...
# 4      spam  FreeMsg Hey there darling it's been 3 week's n...
# ...     ...                                                ...
# 5566   spam  This is the 2nd time we have tried 2 contact u...
# 5567    ham               Will ü b going to esplanade fr home?
# 5568    ham  Pity, * was in mood for that. So...any other s...
# 5569    ham  The guy did some bitching but I acted like i'd...
# 5570    ham                         Rofl. Its true to its name
#
# [5571 rows x 2 columns]
